# %%
#Unzipping the data
# !unzip data.zip
# Out:
# Archive:  data.zip
#   inflating: training_data/training_set.csv
#   inflating: training_data/Evaluator/dummy_detection.csv
#   inflating: training_data/Evaluator/gold_detection.csv
#   inflating: training_data/README.pdf
#   inflating: training_data/Evaluator/dummy_resolution.csv
#   inflating: training_data/detection_answers_file.xlsx
#   inflating: training_data/Evaluator/gold_resolution.csv
#   inflating: training_data/Evaluator/evaluate.jar
#   inflating: training_data/disambiguation_answers_file.csv
#   inflating: training_data/detection_answers_file.csv
#   inflating: training_data/training_set.xlsx
#   inflating: training_data/disambiguation_answers_file.xlsx

# %%
#Importing required libraries.
import pandas as pd
from bs4 import BeautifulSoup
import spacy
import re
import csv
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('tagsets')
nlp = spacy.load("en_core_web_sm")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package tagsets to /root/nltk_data...
# [nltk_data]   Unzipping help/tagsets.zip.

# %%
#Loading training data and labels.
data = pd.read_excel("/content/training_data/training_set.xlsx")
labels = pd.read_excel("/content/training_data/detection_answers_file.xlsx")

# %%
#Encoding labels as 0 and 1.
labels["decision"] = labels.decision.eq("UNAMBIGUOUS", fill_value=1).mul(1)
#Merging training data with labels.
df = pd.merge(data,labels,on="sent_id")
sentences = []
pronouns = []
#Extracting candidate ambiguous pronouns and their starting and ending indices.
for sent in df.sent.values:
  occurences_1 = [(m.start(), m.end(), m.end() - m.start()) for m in re.finditer(r'<referential.{0,8}>', sent)]
  occurences_2 = [(m.start(), m.end(), m.end() - m.start()) for m in re.finditer('</referential>', sent)]
  occurences = zip(occurences_1[1:],occurences_2[1:])
  #Manually add first occurence to prevent redundant ',' occurences_2[0] - occurences_1[2]
  #Pronoun column in the data frame filled with values follows the pattern of PRONOUN#START_INDEX$END_INDEX.
  pronoun_to_append = str(sent[occurences_1[0][1]:occurences_2[0][0]]) + "#" + str(occurences_1[0][0]) + "$" + str(occurences_1[0][0] + (occurences_2[0][0] - occurences_1[0][1]))
  counter = occurences_1[0][2] + occurences_2[0][2]
  for occ in occurences:
    pronoun = "," + str(sent[occ[0][1]:occ[1][0]]) + "#" + str(occ[0][0] - counter) + "$" + str(occ[0][0] + (occ[1][0] - occ[0][1]) - counter)
    pronoun_to_append += pronoun
    counter += occ[0][2] + occ[1][2]
  pronouns.append(pronoun_to_append)
  #Using BeautifulSoup for parsing.
  soup = BeautifulSoup(sent, "html.parser")
  sentences.append(soup.get_text())

#Constructing data frame of training set.
df["category"] = df.apply(lambda row: row[0].split("#")[0], axis=1)
df["pronoun"] = pronouns
df["sent_id_in_category"] = df.apply(lambda row: int(row[0].split("#")[1]), axis=1)
df["sent"] = sentences

# %%
df
# Out:
#         sent_id  ... sent_id_in_category
# 0    library#01  ...                   1
# 1    library#02  ...                   2
# 2    library#03  ...                   3
# 3    library#04  ...                   4
# 4    library#05  ...                   5
# ..          ...  ...                 ...
# 125    space#16  ...                  16
# 126    space#17  ...                  17
# 127    space#18  ...                  18
# 128    space#19  ...                  19
# 129    space#20  ...                  20
#
# [130 rows x 6 columns]

# %%
#Defining singular and plural pronouns.
singular_suffixes = ["i", "you", "he", "she", "it", "me","him", "her", "my", "your", "his", "its", "mine", "yours" ,"hers", "myself", "yourself", "himself", "herself", "itself"]
plural_suffixes = ["we", "you", "they", "us", "them", "our", "your", "their", "ours", "yours", "theirs", "ourselves", "yourselves", "themselves"]

# %%
predictions = []
replaces = []
for sent, pronouns_with_indices in zip(df.sent.values, df.pronoun.values):
  doc = nlp(sent)
  print(sent)
  end_index = 0
  unambiguous = True
  print(pronouns_with_indices)

  for pronoun_splitted in pronouns_with_indices.split(','):
    #Retrieving the pronoun and its start and end indices.
    pronoun = pronoun_splitted.split('#')[0]
    indices = pronoun_splitted.split("#")[1]
    start_index = int(indices.split('$')[0])
    counter = 0
    chunks = []
    correct_chunks = []
    if pronoun in singular_suffixes:
      #If a given pronoun is a singular pronoun, following rules will be applied.
      for chunk in doc.noun_chunks:
        #Looping through for each noun chunk in the sentence.
        text = chunk.text
        idx = sent.find(text)
        print(text)
        #If we find a noun that is after the given pronoun, end the loop. 
        if not (idx < start_index):
          break
        #Otherwise, candidate noun chunks will be appended to chunks list.
        chunks.append(chunk)
        last_chunk = text.split(" ")[-1]
        #Forach token in the sentence
        for i, token in enumerate(doc):
            """
            Rule 1: The token equals to the last chunk in the sentence 
            and has the same starting index with chunk.
            """
          if token.text == last_chunk and token.idx == (chunk.end_char - len(token.text)):
            """
            Rule 2: Token has the tag of "NNP" or "NN".
            Token is not equal to "data" (denotes a plural noun since the singular form of data is "datum") 
            or contains "each of" phrase.
            """
            if token.tag_ == "NNP" or token.tag_ == "NN" or token.text == "data" or (i >= 2 and "each of" == (doc[chunk.start - 2].text + " " + doc[chunk.start - 1].text).lower()):
              if i != len(doc):
            """
            Rule 3: Token has not a following "prepositional phrase(PP)" and does not present after a given pronoun.
            """
                if doc[i+1].pos_ == "ADP" and sent[start_index:].find(token.text) != -1:
                  continue
            """
            Rule 4: Token has not a following "of" PP and a noun or pronoun.
            """                
                if i+1 != len(doc) and doc[i+1].text == "of" and (doc[i+2].pos_ == "NOUN" or doc[i+2].text == pronoun):
                  continue
            """
            Rule 5: Pronoun is not represent a gender and words that denotes pronouns with gender.
            """                   
                if (pronoun == "he" or pronoun == "him" or pronoun == "she" or pronoun == "her") and not (token.text == "driver" or token.text == "user" or token.text == "leader"):
                  continue

              print(chunk)
              counter += 1
              correct_chunks.append(chunk)
            break
    #If a given pronoun is a plural pronoun, following rules will be applied.
    if pronoun in plural_suffixes:
      #Looping through for each noun chunk in the sentence.
      for chunk in doc.noun_chunks:
        text = chunk.text
        idx = sent.find(text)
        print(text)
        #If we find a noun that is after the given pronoun, end the loop. 
        if not (idx < start_index):
          break
        #Otherwise, candidate noun chunks will be appended to chunks list.
        chunks.append(chunk)
        last_chunk = text.split(" ")[-1]
        #Forach token in the sentence
        for i, token in enumerate(doc):
            """
            Rule 1: The token equals to the last chunk in the sentence 
            and has the same starting index with chunk.
            """            
          if token.text == last_chunk and token.idx == (chunk.end_char - len(token.text)):
            """
            Rule 2: Token has the tag of "NNS" or
            Token contains special names as "NLM, ETCS and (s" or 
            Token is equal to "metadata, scheduler and user"
            """            
            if token.tag_ == "NNS" or token.text == "metadata" or token.text == "scheduler" or token.text == "user" or token.text[-2:] == "(s" or token.text == "NLM" or token.text == "ETCS":           
              if i != len(doc):
            """
            Rule 3: Token has not a following "ADP" and parts of token does not present after a given pronoun.
            """                
                if doc[i+1].pos_ == "ADP" and sent[start_index:].find(token.text[:-3]) != -1:
                  continue
            """
            Rule 4: Token has not a following "of" PP and a noun or pronoun.
            """                  
                if i+1 != len(doc) and doc[i+1].text == "of" and (doc[i+2].pos_ == "NOUN" or doc[i+2].text == pronoun):
                  continue
              print(chunk)
              counter += 1
              correct_chunks.append(chunk)

#If only chunk satisfies these rules, counter will be 1 that denotes unabiguous sentences.   
    print(counter)
    if counter != 1:
      unambiguous = False
      break
#Printing the pronoun with associated class.
    end_index = int(indices.split('$')[1])
  print(unambiguous)
#Asserting that unambiguous sentences only contains one correct resolution and classify them as unambiguous after assertion.
  if unambiguous:
    assert len(correct_chunks) == 1
    predictions.append(1)
  else:
    predictions.append(0)
#Appending resolution answers to a list.  
  replaces.append(correct_chunks)
  print(" ")
# Out:
# All material that is stored in the repository will enter it via the Ingest function.
# it#57$59
# All material
# All material
# the repository
# the repository
# it
# the Ingest function
# 2
# False
#
# The library may want to accept important digital materials in non-standard formats in case we are able to migrate them to a more usable format in the future.
# them#114$118
# The library
# important digital materials
# important digital materials
# non-standard formats
# case
# we
# them
# 1
# True
#
# Once material has arrived, it must undergo several reviews, including virus checking, format compliance and anticipated content and file type.
# it#27$29
# material
# material
# it
# 1
# True
#
# Allows resources to be reviewed before a decision is made whether they should be retained.
# they#66$70
# Allows
# resources
# resources
# a decision
# they
# 1
# True
#
# Allows metadata to be stored in a database in a manner that conforms to repository reformatting and linked to their corresponding objects via an identifier.
# their#110$115
# Allows
# metadata
# metadata
# a database
# a manner
# their corresponding objects
# 1
# True
#
# The Coordinate Updates function also incorporates the storage identification information into the Descriptive Information for the AIP and transfers it to the Data Management entity along with a database update request.
# it#148$150
# The Coordinate Updates function
# The Coordinate Updates function
# the storage identification information
# the storage identification information
# the Descriptive Information
# the Descriptive Information
# the AIP
# the AIP
# it
# 4
# False
#
# Archival Storage functions include receiving AIPs from Ingest and adding them to permanent storage, managing the storage hierarchy, refreshing the media on which archive holdings are stored, performing routine and special error checking, providing disaster recovery capabilities, and providing AIPs to Access to fulfill orders.
# them#73$77
# Archival Storage functions
# Archival Storage functions
# AIPs
# Ingest
# them
# 1
# True
#
# It will also conform to any special levels of service required for the AIP, or any special security measures that are required, and ensures the appropriate level of protection for the AIP.
# It#0$2
# 0
# False
#
# It monitors error logs to ensure AIPs are not corrupted during transfers.
# It#0$2
# 0
# False
#
# However, the data constituting the Packaging Information may be changed as long as it continues to perform the same function and there is a straightforward implementation that does not cause information loss.
# it#83$85
# the data
# the data
# the Packaging Information
# the Packaging Information
# it
# the same function
# 2
# False
#
# The migration strategy must select a storage medium, taking into consideration the expected and actual rates of errors encountered in various media types, their performance, and their costs of ownership.
# their#155$160,their#178$183
# The migration strategy
# a storage medium
# consideration
# the expected and actual rates
# errors
# errors
# various media types
# various media types
# their performance
# 2
# False
#
# This function receives an AIP request that identifies the requested AIP(s) and provides them on the requested media type or transfers them to a staging area."
# them#88$92,them#134$138
# This function
# an AIP request
# the requested AIP(s
# the requested AIP(s
# them
# 1
# This function
# an AIP request
# the requested AIP(s
# the requested AIP(s
# them
# the requested media type
# them
# a staging area
# 1
# True
#
# The Generate Report function receives a report request from Ingest, Access or Administration and executes any queries or other processes necessary to generate the report that it supplies to the requester.
# it#175$177
# The Generate Report function
# The Generate Report function
# a report request
# Ingest
# Ingest
# Access
# Access
# Administration
# Administration
# any queries
# other processes
# the report
# the report
# it
# 5
# False
#
# It may also receive a report request from Access and provides descriptive information for a specific AIP.
# It#0$2
# 0
# False
#
# Administration functions include soliciting and negotiating submission agreements with producers, auditing submissions to ensure that they meet archive standards, and maintaining configuration management of system hardware and software.
# they#134$138
# Administration functions
# Administration functions
# submission agreements
# submission agreements
# producers
# producers
# auditing submissions
# auditing submissions
# they
# 4
# False
#
# Audits data in SIPs or AIPs to ensure that they meet specified requirements.
# they#43$47
# Audits
# data
# SIPs
# SIPs
# AIPs
# they
# 1
# True
#
# The Activate Requests function maintains a record of event-driven requests and periodically compares it to the contents of the archive to determine if all needed data is available.
# it#101$103
# The Activate Requests function
# The Activate Requests function
# a record
# event-driven requests
# it
# 1
# True
#
# Maintains a record of event-driven events and compares it to the contents of the repository.
# it#55$57
# a record
# event-driven events
# it
# 0
# False
#
# The Monitor Designated Community function interacts with archive Consumers and Producers to track changes in their service requirements and available product technologies.
# their#109$114
# The Monitor Designated Community function
# archive Consumers
# Producers
# changes
# changes
# their service requirements
# 1
# True
#
# Interacts with repository users and content providers to track changes in their service requirements and available product technologies.
# their#74$79
# Interacts
# Interacts
# repository users
# repository users
# content providers
# content providers
# changes
# changes
# their service requirements
# 4
# False
#
# This function receives reports from the Monitor Designated Communities and Monitor Technology functions, and it receives performance information, inventory reports and summarized consumer comments from Administration.
# it#109$111
# This function
# This function
# reports
# the Monitor Designated Communities and Monitor Technology functions
# it
# performance information
# 1
# True
#
# This function also receives external data standards from Monitor Technology and produces profiles of those standards that are sent to Administration as proposals on their potential usage.
# their#165$170
# This function
# external data standards
# external data standards
# Monitor Technology
# profiles
# profiles
# those standards
# those standards
# Administration
# proposals
# proposals
# their potential usage
# 4
# False
#
# Produces profiles of those standards that are sent to Administration as proposals on their potential usage.
# their#85$90
# profiles
# profiles
# those standards
# those standards
# Administration
# proposals
# proposals
# their potential usage
# 3
# False
#
# NLM will test preservation actions in order to determine their effectiveness across a range of digital objects.
# their#57$62
# NLM
# NLM
# preservation actions
# preservation actions
# order
# their effectiveness
# 2
# False
#
# NLM System Administration/Programming Access, ultimate rights to the system, required for its management, development, and for assigning appropriate rights to users.
# its#90$93
# NLM System Administration/Programming Access
# NLM System Administration/Programming Access
# ultimate rights
# the system
# the system
# its management
# 2
# False
#
# The Clarus system shall process data as they are received.
# they#40$44
# The Clarus system
# data
# data
# they
# 1
# True
#
# The Clarus system shall be able to base its quality control process on values from multiple observations.
# its#40$43
# The Clarus system
# The Clarus system
# its quality control process
# 1
# True
#
# The Clarus system shall be able to communicate with RWIS databases through their native interfaces.
# their#75$80
# The Clarus system
# RWIS databases
# RWIS databases
# their native interfaces
# 1
# True
#
# The Clarus system shall be able to collect data from sources within 5 minutes of them becoming available.
# them#81$85
# The Clarus system
# data
# data
# sources
# sources
# 5 minutes
# them
# 2
# False
#
# The CAS shall be configurable to allow new observation types to be implemented as they become available.
# they#82$86
# The CAS
# new observation types
# new observation types
# they
# 1
# True
#
# CS shall collect environmental data based on its configured schedule.
# its#45$48
# CS
# CS
# environmental data
# environmental data
# its configured schedule
# 2
# False
#
# CS shall be able to dynamically adjust its retrieval schedules when environmental data is expected to be ready but is temporarily delayed.
# its#39$42
# CS
# CS
# its retrieval schedules
# 1
# True
#
# CS shall process environmental data as they are received.
# they#39$43
# CS
# environmental data
# environmental data
# they
# 1
# True
#
# The Clarus system shall be able to communicate with environmental sensor stations through its collector using the NTCIP ESS 1204.
# its#90$93
# The Clarus system
# The Clarus system
# environmental sensor stations
# its collector
# 1
# True
#
# CS shall be able to accept data from an RWIS database in its native output format.
# its#57$60
# CS
# CS
# data
# data
# an RWIS database
# an RWIS database
# its native output format
# 3
# False
#
# The Clarus system shall be able to communicate with an individual ESS through its native interface.
# its#78$81
# The Clarus system
# The Clarus system
# an individual ESS
# an individual ESS
# its native interface
# 2
# False
#
# The DOG shall be able to monitor new environmental data services as they are added.
# they#68$72
# The DOG
# new environmental data services
# new environmental data services
# they
# 1
# True
#
# The DOG shall be able to record its activities.
# its#32$35
# The DOG
# The DOG
# its activities
# 1
# True
#
# The QEDC shall maintain observations and their associated quality flags for seven days.
# their#41$46
# The QEDC
# observations
# observations
# their associated quality flags
# 1
# True
#
# The QEDC shall support queries for its observations.
# its#35$38
# The QEDC
# The QEDC
# queries
# its observations
# 1
# True
#
# QEDS shall log their activities.
# their#15$20
# QEDS
# their activities
# 0
# False
#
# QChS shall be able to base its quality checking process on values distributed in time.
# its#27$30
# QChS
# QChS
# its quality checking process
# 1
# True
#
# The contributors shall define the units of measurements of their shared data and information.
# their#59$64
# The contributors
# The contributors
# the units
# measurements
# their shared data
# 1
# True
#
# The Clarus program shall determine how it will provide data and information to contributors.
# it#39$41
# The Clarus program
# The Clarus program
# it
# 1
# True
#
# The Clarus program shall inform contributors of the acceptance and use of their data and information.
# their#74$79
# The Clarus program
# contributors
# contributors
# the acceptance
# use
# their data
# 1
# True
#
# The logon screen shall activate command control for the user if the user requests it and has authorization.
# it#82$84
# The logon screen
# The logon screen
# command control
# command control
# the user
# the user
# the user
# the user
# it
# 4
# False
#
# When a device status has been overridden, on the screen it shall appear with different color from the normal and alarm status colors.
# it#56$58
# a device status
# a device status
# the screen
# the screen
# it
# 2
# False
#
# It shall display and allow modification of all database tables with the exception of log tables.
# It#0$2
# 0
# False
#
# The user should not be able to update log entries other than for their own login, for the current day and current shift.
# their#65$70
# The user
# The user
# log entries
# log entries
# their own login
# 2
# False
#
# Any change in device state shall be reported on the screen not later than 2 seconds from the time it occurs.
# it#98$100
# Any change
# Any change
# device state
# device state
# the screen
# the screen
# 2 seconds
# the time
# the time
# it
# 4
# False
#
# When each workstation and control unit (workstation or intelligent controller at the FCU or DCU) comes online, the system shall identify it and all its associated device sensors."
# it#137$139,its#148$151
# each workstation and control unit
# each workstation and control unit
# workstation
# workstation
# controller
# controller
# the FCU
# the FCU
# DCU
# DCU
# the system
# the system
# it
# all its associated device sensors
# 6
# False
#
# The RLCS software shall initialize each control unit and device sensor as it is identified.
# it#74$76
# The RLCS software
# The RLCS software
# each control unit
# each control unit
# device sensor
# device sensor
# it
# 3
# False
#
# The devices can be manually controlled/operated from their cabinets (e.g.": Gates)."
# their#53$58
# The devices
# The devices
# their cabinets
# 1
# True
#
# The normal operating mode is Monday through Friday, between 5:00am and 8:00pm, but the system must be functional in order to stay in its closed state after hours.
# its#133$136
# The normal operating mode
# The normal operating mode
# Monday
# Monday
# Friday
# Friday
# the system
# the system
# order
# order
# its closed state
# 5
# False
#
# ETCS shall provide the driver with information to allow him to drive the train safely.
# him#56$59
# ETCS
# the driver
# the driver
# information
# him
# 1
# True
#
# If the supervision is performed by a RBC it shall be possible to prevent movements of a traction unit in its area if not authorised by the RBC."
# it#41$43,its#105$108
# the supervision
# the supervision
# a RBC
# a RBC
# it
# 2
# False
#
# It shall be possible to implement one or more of the ETCS application levels on a line.
# It#0$2
# 0
# False
#
# ETCS shall be compatible with existing national systems listed in the CCS TSI such that it does not interfere with the national systems and is not interfered with by the national systems.
# it#88$90
# ETCS
# ETCS
# existing national systems
# the CCS TSI
# the CCS TSI
# it
# the national systems
# 2
# False
#
# If an ETCS equipped train passes a level transition to a line fitted with more than one level, the onboard shall switch to the highest level, according to the priority given by trackside, for which it is equipped.
# it#198$200
# an ETCS
# an ETCS
# a level transition
# a level transition
# a line
# a line
# more than one level
# more than one level
# the onboard
# the onboard
# the highest level
# the highest level
# the priority
# the priority
# it
# 7
# False
#
# On request of the RBC, the driver shall have the possibility to confirm that the track ahead of him until the end of the on sight section is clear.
# him#96$99
# request
# the RBC
# the driver
# the driver
# the possibility
# the track
# him
# 1
# True
#
# The braking curves shall ensure that the train complies with its speed requirements.
# its#61$64
# The braking curves
# its speed requirements
# 0
# False
#
# If the release speed is calculated on board it shall ensure that the train will stop before reaching the danger point.
# it#44$46
# the release speed
# the release speed
# board
# board
# it
# 2
# False
#
# A train shall be supervised to its static and dynamic train speed profiles.
# its#31$34
# A train
# A train
# its static and dynamic train speed profiles
# 1
# True
#
# Within the braking curve area, a warning shall be given to the driver to enable him to react and avoid intervention from ETCS equipment at least 5 sec before the intervention.
# him#80$83
# the braking curve area
# a warning
# the driver
# the driver
# him
# 1
# True
#
# The ETCS trainborne equipment shall transmit its own train identification to the RBC.
# its#45$48
# The ETCS trainborne equipment
# The ETCS trainborne equipment
# its own train identification
# 1
# True
#
# If a train cannot stop at the proposed new target location it shall reject the request and keep the old target location.
# it#59$61
# a train
# a train
# the proposed new target location
# the proposed new target location
# it
# 2
# False
#
# The train may proceed unrestricted to the end of its movement authority.
# its#49$52
# The train
# The train
# the end
# its movement authority
# 1
# True
#
# It is acceptable that only one mobile user involved in the group call may talk at any time.
# It#0$2
# 0
# False
#
# If the text message facility is implemented, it shall not interfere with the ability of users to make or receive high priority voice or data calls.
# it#45$47
# the text message facility
# the text message facility
# it
# the ability
# 1
# True
#
# Where fax functionality is provided, it shall be possible to interrupt the fax to make or receive a high priority voice or data call.
# it#37$39
# fax functionality
# fax functionality
# it
# the fax
# 1
# True
#
# The network shall provide the ability to inform a user, who is involved in an existing call, of attempts by other users to contact them.
# them#131$135
# The network
# the ability
# a user
# a user
# who
# an existing call
# attempts
# attempts
# other users
# other users
# them
# 3
# False
#
# Where network services are chargeable, it should be possible for the network to provide information about call rates and on-going call charges.
# it#39$41
# network services
# it
# 0
# False
#
# Picking up the handset shall transfer the communication to the handset and reduce the loudspeaker volume to its minimum level.
# its#108$111
# the handset
# the handset
# the communication
# the communication
# the handset
# the handset
# the loudspeaker volume
# the loudspeaker volume
# its minimum level
# 4
# False
#
# An indication shall be provided to the driver as a reminder of the need to use the Push-To-Talk button on the handset if he wants to talk.
# he#121$123
# An indication
# the driver
# the driver
# a reminder
# the need
# Talk
# the handset
# he
# 1
# True
#
# It shall be possible for a driver to initiate railway emergency calls (see section 13).
# It#0$2
# 0
# False
#
# If the train moves out of the call area whilst the call is in progress, it will leave the call and an audible and visual indication of the loss of call shall be provided to the driver.
# it#72$74
# the train
# the train
# the call area
# the call area
# the call
# the call
# progress
# progress
# it
# 4
# False
#
# Once the driver has accepted the standard point-to-point call, it shall be connected appropriately, eg if the driver has accepted the call by lifting the handset, then the call shall be routed to the handset.
# it#63$65
# the driver
# the driver
# point
# point
# it
# 2
# False
#
# In this case, the security device alerts the driver if the link has failed or if it is cancelled.
# it#81$83
# this case
# this case
# the security device
# the security device
# the driver
# the driver
# the link
# the link
# it
# 4
# False
#
# It should be possible for the Cab radio to be used without the network service (if it should fail or if there is no authorised network coverage) such that local open channel communications are still possible."
# It#0$2,it#83$85
# 0
# False
#
# Where the Cab radio is required by a national railway to support a handheld portable, the Cab radio shall: - provide a clear indication as to whether the handheld portable is activated or not; - provide an interface to allow the handheld portable to be recharged when not in use; - forward calls automatically to the handheld portable when the handheld portable is activated; - cancel any call forwarding to the handheld portable when it is deactivated; - allow the driver to override the call forwarding to the handheld portable.
# it#435$437
# the Cab radio
# the Cab radio
# a national railway
# a national railway
# a handheld portable
# a handheld portable
# the Cab radio
# the Cab radio
# a clear indication
# a clear indication
# the handheld portable
# the handheld portable
# an interface
# an interface
# use
# use
# forward
# forward
# the handheld portable
# the handheld portable
# the handheld portable
# the handheld portable
# any call
# any call
# the handheld portable
# the handheld portable
# it
# 13
# False
#
# When the MMI is switched on, the configuration shall be determined by the time elapsed since the MMI was last switched off: - less than t minutes – the MMI shall power up with the same configuration as when it was last powered down; - greater than t minutes – the MMI shall power up with default settings.
# it#207$209
# the MMI
# the MMI
# the configuration
# the configuration
# the time
# the time
# the MMI
# the MMI
# the MMI
# the MMI
# the same configuration
# the same configuration
# it
# t minutes
# the MMI
# the MMI
# default settings
# 7
# False
#
# If directed network selection is implemented, input from the external device(s) shall initiate the network change regardless of the identity of the current network and how it was selected.
# it#172$174
# directed network selection
# directed network selection
# the network change
# the network change
# the identity
# the identity
# the current network
# the current network
# it
# 4
# False
#
# Non leading drivers shall be able to indicate to the system their location in the train during the registration procedure (2nd driver, 3rd driver etc).
# their#60$65
# leading drivers
# leading drivers
# the system
# their location
# 1
# True
#
# Each type of equipment has slightly different requirements placed upon it in terms of EMC and climate.
# it#71$73
# Each type
# equipment
# equipment
# slightly different requirements
# it
# 1
# True
#
# The design of the equipment shall make it possible to install it within a cab complying with the requirements of UIC fiche 651 concerning the layout of cab equipment5."
# it#39$41,it#62$64
# The design
# The design
# the equipment
# the equipment
# it
# 2
# False
#
# If the call is a broadcast call, the user shall be informed that he cannot speak as part of the broadcast call.
# he#65$67
# the call
# a broadcast call
# the user
# the user
# he
# part
# 1
# True
#
# Where a change of functional number is required, it shall be possible for the user to initiate the change.
# it#49$51
# a change
# functional number
# functional number
# it
# 1
# True
#
# It shall be possible for the user to find and display stored numbers and their information."
# It#0$2,their#73$78
# 0
# False
#
# The Operational radio is specified to allow its use in the operating environment experienced on the operational railway# (eg shunting and maintenance)."
# its#44$47
# The Operational radio
# The Operational radio
# its use
# 1
# True
#
# Controls shall be designed such that they are suitable for use by people wearing gloves.
# they#37$41
# Controls
# Controls
# they
# 1
# True
#
# It should be possible for the system to prevent certain types of users from registering functional numbers that they are not authorised to use."
# It#0$2,they#112$116
# 0
# False
#
# As a minimum, the location information used by the EIRENE system shall be derived from that available from the network itself (eg current cell or base station serving the mobile).
# itself#119$125
# a minimum
# a minimum
# the location information
# the location information
# the EIRENE system
# the EIRENE system
# the network
# the network
# itself
# 4
# False
#
# After the 30 second period, if the connection was unsuccessful, the system shall provide another audible and visual indication that it was unable to connect the call.
# it#132$134
# the 30 second period
# the 30 second period
# the connection
# the connection
# the system
# the system
# another audible and visual indication
# another audible and visual indication
# it
# 4
# False
#
# For post-incident analysis, it is important that the origination and reception of railway# emergency calls by mobiles is confirmed by a message sent to a ground-based central location (and also recorded in the on-train recording device)."
# it#28$30
# post-incident analysis
# post-incident analysis
# it
# 1
# True
#
# Throughout the duration of the shunting group call, it shall be possible for any member of the shunting group to speak to all other members of the group, using the PTT function (as described in sections 5.2.2.53, 6.2.2.12 and 7.2.2.20), except during transmission of the link assurance signal.
# it#52$54
# the duration
# the duration
# the shunting group call
# the shunting group call
# it
# 2
# False
#
# The shunting leader can then choose the moment when he takes or rejects the call.
# he#52$54
# The shunting leader
# The shunting leader
# the moment
# he
# the call
# 1
# True
#
# In this case, the safety device will alert the driver only if the link assurance signal has failed or if it is cancelled.
# it#105$107
# this case
# this case
# the safety device
# the safety device
# the driver
# the driver
# the link assurance signal
# the link assurance signal
# it
# 4
# False
#
# 300ms represents our current best estimate of the QoS figure, although this will need to be confirmed through user trials.
# our#17$20
# 300ms
# our current best estimate
# 0
# False
#
# Each authority can decide whether it wishes to use synchronised BTSs.
# it#34$36
# Each authority
# Each authority
# it
# synchronised BTSs
# 1
# True
#
# The network shall terminate the ongoing VGCS/VBS call if it receives the 3-digit sequence “***” transmitted via DTMF signals.
# it#57$59
# The network
# The network
# the ongoing VGCS/VBS call
# the ongoing VGCS/VBS call
# it
# 2
# False
#
# The network shall send the SET-PARAMETER message with the attribute “D-ATT = T”1 [EN 301 515, Index [6]] to the mobile station of the talking subscriber if it receives the 3- digit sequence “ddd” transmitted via DTMF or the group call SETUP message2 from a controller terminal.
# it#156$158
# The network
# The network
# the SET-PARAMETER message
# the attribute
# the attribute
# [EN
# Index
# Index
# the mobile station
# the mobile station
# the talking subscriber
# the talking subscriber
# it
# DTMF
# 5
# False
#
# When the network has detected the 3-digit DTMF sequence “ddd” transmitted via DTMF from a controller terminal and if the controller was not previously talking it should indicate its recognition by playing a single DTMF grant tone “?” of duration of 100ms  5ms to be sent to that controller terminal only."
# it#159$161,its#178$181
# the network
# the network
# DTMF
# a controller terminal
# a controller terminal
# the controller
# the controller
# it
# its recognition
# 3
# False
#
# The network shall send the SET-PARAMETER message with the attribute “D-ATT = F”3 [EN 301 515, Index [6]] to the mobile of the talking subscriber only if it has received the 3-digit sequence “dDD” transmitted via DTMF from all the talking controllers4.
# it#153$155
# The network
# The network
# the SET-PARAMETER message
# the SET-PARAMETER message
# the attribute
# the attribute
# [EN
# Index
# Index
# the mobile
# the mobile
# the talking subscriber
# the talking subscriber
# it
# the 3-digit sequence
# 6
# False
#
# Many of the railway specific standards referenced are Pre-standards (eg [prEN 50155, ENV 50121, prEN 50125]) and should be re-examined for their applicability to the EIRENE system if any modifications are made to these standards in the future.
# their#139$144
# the railway specific standards
# the railway specific standards
# Pre-standards
# ENV
# prEN
# their applicability
# 1
# True
#
# Each of the other cabs on the train will be contacted using its functional number (registered by the other drivers prior to the establishment of the call).
# its#60$63
# the other cabs
# the other cabs
# the train
# the train
# its functional number
# 2
# False
#
# Upon registration, the mobile shall be accessible by calling the MSISDN or the Engine or Coach number with which it is associated.
# it#113$115
# registration
# registration
# the mobile
# the mobile
# the MSISDN
# the MSISDN
# the Engine
# the Engine
# Coach
# Coach
# number
# number
# it
# 6
# False
#
# The Cab radio system shall provide a means for the driver to terminate established calls which he is authorised to terminate.
# he#95$97
# The Cab radio system
# a means
# the driver
# the driver
# established calls
# he
# 1
# True
#
# The Digitalhome programmable Appliance Manager shall provide for management of a home’s small appliances, including lighting units, by allowing a user to turn them on or off as desired.
# them#159$163
# The Digitalhome programmable Appliance Manager
# management
# a home’s small appliances
# a home’s small appliances
# lighting units
# lighting units
# a user
# a user
# them
# 3
# False
#
# Although the product produced under this document will be a “prototype” version, all modules and components of this prototype version shall be designed and implemented in such a manner that it may be incorporated in a fully specified commercial version of the Digitalhome System.
# it#190$192
# the product
# the product
# this document
# this document
# a “prototype” version
# a “prototype” version
# all modules
# components
# this prototype version
# this prototype version
# such a manner
# such a manner
# it
# 5
# False
#
# The Digitalhome System shall provide users with online documentation about the Digitalhome system installed in their home.
# their#111$116
# The Digitalhome System
# users
# users
# online documentation
# the Digitalhome system
# their home
# 1
# True
#
# The FCP shall, if the NEFU ICP fails to send its ICP Ready signal, mask out that ICP, but continue to use the NE.16."
# its#45$48
# The FCP
# The FCP
# the NEFU ICP
# the NEFU ICP
# its ICP Ready signal
# 2
# False
#
# Each rate group has some number of tasks associated with it and it also has a rate for those tasks."
# it#57$59,it#64$66
# Each rate group
# Each rate group
# some number
# tasks
# it
# it
# a rate
# 1
# Each rate group
# Each rate group
# some number
# tasks
# it
# it
# a rate
# 1
# True
#
# The enabled tasks are then unblocked at the rate given in its associated rate group.
# its#58$61
# The enabled tasks
# the rate
# the rate
# its associated rate group
# 1
# True
#
# An API call is available for the task to call to block itself when it is finished with its cyclic processing."
# it#67$69,its#87$90
# An API call
# An API call
# the task
# the task
# itself
# it
# its cyclic processing
# 2
# False
#
# There is up to a full major frame from notification of an impending mode change to acting on it in minor frame 0 of the next major frame plus the time it takes during the next minor frame 0 to switch tasking."
# it#93$95,it#151$153
# a full major frame
# notification
# notification
# an impending mode change
# an impending mode change
# it
# 2
# False
#
# The scheduler shall execute cyclic tasks, providing an API call to allow the application to block until its next iteration.
# its#104$107
# The scheduler
# The scheduler
# cyclic tasks
# an API call
# an API call
# the application
# the application
# its next iteration
# 3
# False
#
# The scheduler shall give tasks priority values according to their rate - the higher the rate, the higher the priority.
# their#60$65
# The scheduler
# The scheduler
# tasks priority values
# tasks priority values
# their rate
# 2
# False
#
# The scheduler shall provide a mechanism to inform a task when it did not complete during the previous frame and restart it at the beginning of the task."
# it#62$64,it#120$122
# The scheduler
# The scheduler
# a mechanism
# a mechanism
# a task
# a task
# it
# 3
# False
#
# All tasks in rate groups and their corresponding schedules for all vehicle modes will be setup at system initialization.
# their#29$34
# All tasks
# All tasks
# rate groups
# rate groups
# their corresponding schedules
# 2
# False
#
# Tasks in a rate group must suspend on a scheduler API call at the top of their execution loop.
# their#73$78
# Tasks
# Tasks
# a rate group
# a scheduler API call
# the top
# their execution loop
# 1
# True
#
# For hardware exceptions and reserved exceptions, the FTSS shall make the error type and its context data available to the application, then return from the exception handler to the task that was running when the exception occurred.
# its#88$91
# hardware exceptions
# reserved exceptions
# the FTSS
# the FTSS
# the error type
# the error type
# its context data
# 2
# False
#
# Messages are addressed with a global unique communication identifier that routes them to the appropriate virtual group (VG) and socket.
# them#81$85
# Messages
# Messages
# a global unique communication identifier
# them
# 1
# True
#
# This restriction does NOT apply to the ICPs since they are running as simplex VGs.
# they#50$54
# This restriction
# the ICPs
# the ICPs
# they
# 1
# True
#
# FTSS shall mask out a babbling NE or ICP within 40 milliseconds after it is detected.
# it#70$72
# FTSS
# FTSS
# a babbling NE
# a babbling NE
# ICP
# ICP
# 40 milliseconds
# it
# 3
# False
#
# Synchronous message passing sockets shall queue outgoing messages until they are transmitted at frame boundaries.
# they#72$76
# Synchronous message passing sockets
# Synchronous message passing sockets
# outgoing messages
# outgoing messages
# they
# 2
# False
#
# Pipes may be opened by multiple receiving tasks if they are created with the broadcast capability; otherwise they may only be opened by one receiving task."
# they#51$55,they#109$113
# Pipes
# Pipes
# multiple receiving tasks
# multiple receiving tasks
# they
# 2
# False
#
# Communication services shall provide the capability to create pipes which "broadcast" their messages to all virtual groups.""
# their#86$91
# Communication services
# Communication services
# the capability
# pipes
# pipes
# their messages
# 2
# False
#
# If the broadcast option is used, each virtual group should open the pipe and read from it to avoid flow control problems.
# it#87$89
# the broadcast option
# the broadcast option
# each virtual group
# each virtual group
# the pipe
# the pipe
# it
# 3
# False
#
# The application software shall have the capability to reset a permanently failed channel to its initial recovery state.
# its#92$95
# The application software
# The application software
# the capability
# the capability
# a permanently failed channel
# a permanently failed channel
# its initial recovery state
# 3
# False
#
# Redundancy Management picks up where it left off in these attempts.
# it#37$39
# Redundancy Management
# Redundancy Management
# it
# 1
# True

# %%
asd = 0
#Comarping predictions with correct annotations.
for idx, (pred, truth) in enumerate(zip(predictions, df.decision.values)):
  if pred == truth:
    asd += 1
  #Printing misclassified samples.
  else:
    print(idx)
    print(df.sent.values[idx])

#Printing total number of misclassifed samples and accuracy.
print(len(predictions) - asd)
print(asd / len(predictions))
# Out:
# 10
# The migration strategy must select a storage medium, taking into consideration the expected and actual rates of errors encountered in various media types, their performance, and their costs of ownership.
# 15
# Audits data in SIPs or AIPs to ensure that they meet specified requirements.
# 16
# The Activate Requests function maintains a record of event-driven requests and periodically compares it to the contents of the archive to determine if all needed data is available.
# 17
# Maintains a record of event-driven events and compares it to the contents of the repository.
# 33
# The Clarus system shall be able to communicate with environmental sensor stations through its collector using the NTCIP ESS 1204.
# 45
# The logon screen shall activate command control for the user if the user requests it and has authorization.
# 46
# When a device status has been overridden, on the screen it shall appear with different color from the normal and alarm status colors.
# 49
# Any change in device state shall be reported on the screen not later than 2 seconds from the time it occurs.
# 53
# The normal operating mode is Monday through Friday, between 5:00am and 8:00pm, but the system must be functional in order to stay in its closed state after hours.
# 56
# It shall be possible to implement one or more of the ETCS application levels on a line.
# 57
# ETCS shall be compatible with existing national systems listed in the CCS TSI such that it does not interfere with the national systems and is not interfered with by the national systems.
# 58
# If an ETCS equipped train passes a level transition to a line fitted with more than one level, the onboard shall switch to the highest level, according to the priority given by trackside, for which it is equipped.
# 60
# The braking curves shall ensure that the train complies with its speed requirements.
# 67
# It is acceptable that only one mobile user involved in the group call may talk at any time.
# 69
# Where fax functionality is provided, it shall be possible to interrupt the fax to make or receive a high priority voice or data call.
# 71
# Where network services are chargeable, it should be possible for the network to provide information about call rates and on-going call charges.
# 74
# It shall be possible for a driver to initiate railway emergency calls (see section 13).
# 76
# Once the driver has accepted the standard point-to-point call, it shall be connected appropriately, eg if the driver has accepted the call by lifting the handset, then the call shall be routed to the handset.
# 79
# Where the Cab radio is required by a national railway to support a handheld portable, the Cab radio shall: - provide a clear indication as to whether the handheld portable is activated or not; - provide an interface to allow the handheld portable to be recharged when not in use; - forward calls automatically to the handheld portable when the handheld portable is activated; - cancel any call forwarding to the handheld portable when it is deactivated; - allow the driver to override the call forwarding to the handheld portable.
# 80
# When the MMI is switched on, the configuration shall be determined by the time elapsed since the MMI was last switched off: - less than t minutes – the MMI shall power up with the same configuration as when it was last powered down; - greater than t minutes – the MMI shall power up with default settings.
# 86
# Where a change of functional number is required, it shall be possible for the user to initiate the change.
# 92
# After the 30 second period, if the connection was unsuccessful, the system shall provide another audible and visual indication that it was unable to connect the call.
# 93
# For post-incident analysis, it is important that the origination and reception of railway# emergency calls by mobiles is confirmed by a message sent to a ground-based central location (and also recorded in the on-train recording device)."
# 96
# In this case, the safety device will alert the driver only if the link assurance signal has failed or if it is cancelled.
# 105
# Upon registration, the mobile shall be accessible by calling the MSISDN or the Engine or Coach number with which it is associated.
# 110
# The FCP shall, if the NEFU ICP fails to send its ICP Ready signal, mask out that ICP, but continue to use the NE.16."
# 112
# The enabled tasks are then unblocked at the rate given in its associated rate group.
# 27
# 0.7923076923076923

# %%
#Printing the resolution for each unambiguous sentence.
for repl, idx in zip(replaces, df.sent_id.values):
  if len(repl) == 1:
    print(idx + "-" + repl[0].text)
# Out:
# library#02-important digital materials
# library#03-material
# library#04-resources
# library#05-metadata
# library#07-Archival Storage functions
# library#12-the requested AIP(s
# library#16-SIPs
# library#17-The Activate Requests function
# library#19-changes
# library#21-This function
# weather#01-data
# weather#02-The Clarus system
# weather#03-RWIS databases
# weather#05-new observation types
# weather#07-CS
# weather#08-environmental data
# weather#09-The Clarus system
# weather#12-new environmental data services
# weather#13-The DOG
# weather#14-observations
# weather#15-The QEDC
# weather#17-QChS
# weather#18-The contributors
# weather#19-The Clarus program
# weather#20-contributors
# railway#08-The devices
# railway#10-the driver
# railway#15-the driver
# railway#18-A train
# railway#19-the driver
# railway#20-The ETCS trainborne equipment
# railway#22-The train
# railway#24-the text message facility
# railway#25-fax functionality
# railway#29-the driver
# railway#38-leading drivers
# railway#39-equipment
# railway#41-the user
# railway#42-functional number
# railway#44-The Operational radio
# railway#45-Controls
# railway#49-post-incident analysis
# railway#51-The shunting leader
# railway#54-Each authority
# railway#59-the railway specific standards
# railway#62-the driver
# home#03-users
# space#02-Each rate group
# space#03-the rate
# space#10-Tasks
# space#12-Messages
# space#13-the ICPs
# space#20-Redundancy Management

# %% [markdown]
# ### Evaluation

# %%
#Creating csv file to evaluate detection performance
df__ = df
df__["decision"] = predictions
df__["decision"].replace({0: "AMBIGUOUS", 1: "UNAMBIGUOUS"}, inplace=True)
df__[["sent_id","decision"]].to_csv('detection.csv',index=False, quotechar='"',quoting=csv.QUOTE_NONNUMERIC)

# %%
#Creating csv file to evaluate resolution performance 
idxs = []
resl = []
#Storing sentences that contains multiple disambiguous pronouns.
double = list(df[df['pronoun'].str.contains(",")]["sent_id"])
lst__ = ["a","b"]
for repl, idx in zip(replaces, df.sent_id.values):
  #For each unambiguous sentence
  if len(repl) == 1:
    if idx in double:
      #If a given sentence contains multiple disambiguous pronouns, we assume that resolution of both pronouns corresponds to the same noun.
      for letter in lst__ :
        idxs.append(idx+"-"+letter)
        resl.append(repl[0].text)
    else:
        # If a given sentence contains single disambiguous pronoun, append its resolution to the list.
        idxs.append(idx)
        resl.append(repl[0].text)    
        
#Creating a dataset with our resolving nouns, this data set will be referred as test set.
df_resolution = pd.DataFrame(data={"sent_id":idxs,"resolution":resl})
#Since we did not achieve %100 accuracy, we form our test set with ids that are present in the golden resolution set.
df_golden = pd.read_csv("/content/training_data/Evaluator/gold_resolution.csv")
#Printing misclassifed samples.
print("Not on golden records: ",set(list(df_resolution["sent_id"])).difference(df_golden["sent_id"]))
#Left joining golden set with test set.
df_resolution_final = df_golden.merge(df_resolution, how="left")
#Deleting duplicate columns.
df_resolution_final = df_resolution_final.drop(df_resolution_final.columns[1], axis=1)
#Filling the sentences that we did not predicted as ambiguous in detection with empty strings.
df_resolution_final = df_resolution_final.fillna(" ")
#Creating csv file to evaluate resolution performance of our system.
df_resolution_final.to_csv('resolution.csv',index=False, quotechar='"',quoting=csv.QUOTE_NONNUMERIC)
# Out:
# Not on golden records:  {'library#17', 'railway#42', 'railway#49', 'space#03', 'railway#25', 'weather#09', 'library#16'}

# %%
#Since we did not achieved %100 accuracy, we have created a hypotetical state that we have correctly classified all the samples
#to evaluate the performance of the rule-based pronoun resolver by using the samples only exists in our resolution answers.
df_golden_reduced = df_golden[df_golden.sent_id.isin(list(df_resolution_final[df_resolution_final["resolution"] != " "]["sent_id"]))]
df_golden_reduced.to_csv('golden_resolution_reduced.csv',index=False, quotechar='"',quoting=csv.QUOTE_NONNUMERIC)
df_resolution_final[df_resolution_final["resolution"] != " "].to_csv('resolution_reduced.csv',index=False, quotechar='"',quoting=csv.QUOTE_NONNUMERIC)
